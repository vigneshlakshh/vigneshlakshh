# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshlakshh/vigneshlakshh/blob/main/Linear_Regression_explained.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SIMPLE LINEAR REGRESSION**
#
# FIND BEST FIT LINE
#
# Eg: exp vs salary , house vs price
#
# independent variable (x) -for given value of x
#
# dependent variable(y)-find the value of y
#
# equation of line y=mx+c ---> m-slope, c-intercept
#
# intercept--> origin to line hit y-axis distance
#
# slope(y2-y1)/(x2-x1)
#
# or  (any two points can be taken)
#
# slope dy/dx

# %% [markdown]
# **MORE THAN TWO VARIABLE-MULTIPLE LINEAR REGRESSION**
#
# find the best fit hyperplane
#
# many independent variable-x1,x2,x3 (bedroom,area,floors)
#
# one dependendent varible-y (price)
#
# y=b0+bi*xi

# %% [markdown]
# **advanatges**- simple,good on linear data
#
# **disadvantages**- not suitable for non-linear,data,underfitting,sensitive to outlier

# %% [markdown]
# **FIND THE BEST FIT LINE**
#
# assigns random values to  m and c initially
#
# **LOSS FUNCTION**--MIN LOSS is The best fit line
#
# **estimated value or predicted value-line**  **(yi^)**--(x,y^)
#
# **true value-data points** **(yi)**  (x,y)
#
# (yi-yi^)^2 for all datapoints/no of data points
#
#
# ![mean-squared-error.png](data:image/png;base64,...)

# %% [markdown]
# **MODEL OPTIMIZATION- GRADIENT DECENT**
#
# **parameter (x-axis) vs loss function(y-axis) -gradient decent**
#
# find best parameters like m,c
#
# so that loss is low and high accuracy
#
#  **global minimum**- if we choose the parameters from that point we get high accuracy and less loss
#  ![image-203.png](data:image/png;base64,...)

# %% [markdown]
# GARDIENT DESCENT
#
# m-slope  or w -weight
#
# c-intercept or b-bias
#
# L-learning rate
#
# Dm-PD of loss w.r.t m
#
# Dc-PD of loss w.r.t.c
#
# m=m-LDm
#
#  **c=c-LDc**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Salary_Data.csv")
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
# %matplotlib inline
plt.scatter(df.YearsExperience,df.Salary,color="red",marker="+")
plt.xlabel("year of exp",fontsize=20)
plt.ylabel("salary",fontsize=20)
# Out:
# Text(0, 0.5, 'salary')

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(df[['YearsExperience']],df.Salary)
# Out:
# LinearRegression()

# %%
print(reg.predict([[17]]))
print(reg.coef_)
print(reg.intercept_)
# Out:
# [186441.5596634]
# [9449.96232146]
# 25792.200198668696
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
